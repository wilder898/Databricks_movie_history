# %%
bronze_folder_path = "abfss://bronze@stmoviesdatabricks.dfs.core.windows.net"
silver_folder_path = "abfss://silver@stmoviesdatabricks.dfs.core.windows.net"
gold_folder_path = "abfss://gold@stmoviesdatabricks.dfs.core.windows.net"
