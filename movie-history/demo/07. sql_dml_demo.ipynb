-- %%
SHOW DATABASES
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>demo</td></tr><tr><td>information_schema</td></tr><tr><td>movie_bronze</td></tr><tr><td>movie_gold</td></tr><tr><td>movie_silver</td></tr></tbody></table></div>

-- %%
SELECT current_database()
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>default</td></tr></tbody></table></div>

-- %%
USE movie_silver

-- %%
SHOW TABLES
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>movie_silver</td><td>countries</td><td>false</td></tr><tr><td>movie_silver</td><td>genres</td><td>false</td></tr><tr><td>movie_silver</td><td>language_roles</td><td>false</td></tr><tr><td>movie_silver</td><td>languages</td><td>false</td></tr><tr><td>movie_silver</td><td>movie_cast</td><td>false</td></tr><tr><td>movie_silver</td><td>movie_genres</td><td>false</td></tr><tr><td>movie_silver</td><td>movies</td><td>false</td></tr><tr><td>movie_silver</td><td>movies_companies</td><td>false</td></tr><tr><td>movie_silver</td><td>movies_languages</td><td>false</td></tr><tr><td>movie_silver</td><td>persons</td><td>false</td></tr><tr><td>movie_silver</td><td>productions_companies</td><td>false</td></tr><tr><td>movie_silver</td><td>productions_countries</td><td>false</td></tr><tr><td></td><td>_sqldf</td><td>true</td></tr></tbody></table></div>

-- %%
SELECT *
FROM movies
LIMIT 100

-- %%
SELECT * FROM movie_silver.movies

-- %%
DESC movies
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>movie_id</td><td>int</td><td>null</td></tr><tr><td>title</td><td>string</td><td>null</td></tr><tr><td>budget</td><td>double</td><td>null</td></tr><tr><td>popularity</td><td>double</td><td>null</td></tr><tr><td>year_release_date</td><td>int</td><td>null</td></tr><tr><td>release_date</td><td>date</td><td>null</td></tr><tr><td>revenue</td><td>double</td><td>null</td></tr><tr><td>duration_time</td><td>int</td><td>null</td></tr><tr><td>vote_average</td><td>double</td><td>null</td></tr><tr><td>vote_count</td><td>int</td><td>null</td></tr><tr><td>ingestion_date</td><td>timestamp</td><td>null</td></tr><tr><td>environment</td><td>string</td><td>null</td></tr></tbody></table></div>

-- %%
SELECT *
FROM movies
WHERE year_release_date = 2015 AND vote_average >= 7.5
ORDER BY vote_average DESC;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movie_id</th><th>title</th><th>budget</th><th>popularity</th><th>year_release_date</th><th>release_date</th><th>revenue</th><th>duration_time</th><th>vote_average</th><th>vote_count</th><th>ingestion_date</th><th>environment</th></tr></thead><tbody><tr><td>346081</td><td>Sardaarji</td><td>2000000</td><td>0.296981</td><td>2015</td><td>2015-06-26</td><td>2600000</td><td>75</td><td>9.5</td><td>2</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>322745</td><td>Counting</td><td>50000</td><td>0.293587</td><td>2015</td><td>2015-02-09</td><td>62500</td><td>111</td><td>8.3</td><td>3</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>264644</td><td>Room</td><td>6000000</td><td>66.11334</td><td>2015</td><td>2015-10-16</td><td>35401758</td><td>117</td><td>8.1</td><td>2757</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>150540</td><td>Inside Out</td><td>175000000</td><td>128.655964</td><td>2015</td><td>2015-06-09</td><td>857611174</td><td>94</td><td>8</td><td>6560</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>357441</td><td>Karachi se Lahore</td><td>2000000</td><td>0.060003</td><td>2015</td><td>2015-07-31</td><td>2600000</td><td>75</td><td>8</td><td>1</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>310569</td><td>Que Horas Ela Volta?</td><td>2000000</td><td>9.683622</td><td>2015</td><td>2015-02-08</td><td>2600000</td><td>110</td><td>7.8</td><td>165</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>314365</td><td>Spotlight</td><td>20000000</td><td>41.503588</td><td>2015</td><td>2015-11-06</td><td>88346473</td><td>128</td><td>7.8</td><td>2686</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>277216</td><td>Straight Outta Compton</td><td>28000000</td><td>61.76233</td><td>2015</td><td>2015-08-13</td><td>201634991</td><td>147</td><td>7.7</td><td>1355</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>264660</td><td>Ex Machina</td><td>15000000</td><td>95.130041</td><td>2015</td><td>2015-01-21</td><td>36869414</td><td>108</td><td>7.6</td><td>4737</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>273248</td><td>The Hateful Eight</td><td>44000000</td><td>68.717016</td><td>2015</td><td>2015-12-25</td><td>155760117</td><td>167</td><td>7.6</td><td>4274</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>286217</td><td>The Martian</td><td>108000000</td><td>167.93287</td><td>2015</td><td>2015-09-30</td><td>630161890</td><td>141</td><td>7.6</td><td>7268</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>309809</td><td>The Little Prince</td><td>64000000</td><td>35.384423</td><td>2015</td><td>2015-07-29</td><td>97571250</td><td>92</td><td>7.6</td><td>756</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr><tr><td>256040</td><td>Baahubali: The Beginning</td><td>40000000</td><td>16.254032</td><td>2015</td><td>2015-07-10</td><td>100000000</td><td>159</td><td>7.5</td><td>135</td><td>2026-08-27T00:14:52.178526Z</td><td>production</td></tr></tbody></table></div>
