-- %%
USE movie_gold;

-- %%
SELECT country_name,
    count(country_name) AS total_movie,
    sum(budget) AS total_budget,
    cast(avg(budget) AS DECIMAL(18,2)) AS avg_budget,
    sum(revenue) AS total_revenue,
    cast(avg(revenue) AS DECIMAL(18,2)) AS avg_revenue
FROM results_movies
GROUP BY country_name
ORDER BY total_revenue DESC
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_name</th><th>total_movie</th><th>total_budget</th><th>avg_budget</th><th>total_revenue</th><th>avg_revenue</th></tr></thead><tbody><tr><td>United States of America</td><td>11217</td><td>466413668159</td><td>41580963.55</td><td>1.2290854921218748E12</td><td>114386737.28</td></tr><tr><td>United Kingdom</td><td>2558</td><td>94067944476</td><td>36774020.51</td><td>2.397750386876613E11</td><td>96839676.37</td></tr><tr><td>Germany</td><td>1512</td><td>62028570052</td><td>41024186.54</td><td>1.2300720639631972E11</td><td>84832556.14</td></tr><tr><td>France</td><td>1574</td><td>37668361602</td><td>23931614.74</td><td>7.490840770337485E10</td><td>50240380.75</td></tr><tr><td>Canada</td><td>986</td><td>30429781547</td><td>30861847.41</td><td>7.187363859167935E10</td><td>74712722.03</td></tr><tr><td>Australia</td><td>432</td><td>20359593808</td><td>47128689.37</td><td>4.116185062289344E10</td><td>98946756.31</td></tr><tr><td>New Zealand</td><td>111</td><td>9199500000</td><td>82878378.38</td><td>3.2572500546374844E10</td><td>293445950.87</td></tr><tr><td>Japan</td><td>222</td><td>8036902228</td><td>36202262.29</td><td>2.8087480798795986E10</td><td>131249910.27</td></tr><tr><td>China</td><td>127</td><td>8549157005</td><td>67316196.89</td><td>2.0562658459465637E10</td><td>169939326.11</td></tr><tr><td>Italy</td><td>383</td><td>12247733808</td><td>31978417.25</td><td>19472755717</td><td>52915097.06</td></tr></tbody></table></div>
-- Databricks data profile. Run in Databricks to view.
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT country_name,
    count(country_name) AS total_movie,
    sum(budget) AS total_budget,
    cast(avg(budget) AS DECIMAL(18,2)) AS avg_budget,
    sum(revenue) AS total_revenue,
    cast(avg(revenue) AS DECIMAL(18,2)) AS avg_revenue
    
FROM results_movies
WHERE year_release_date BETWEEN 2010 AND 2015
GROUP BY country_name
ORDER BY total_revenue DESC
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country_name</th><th>total_movie</th><th>total_budget</th><th>avg_budget</th><th>total_revenue</th><th>avg_revenue</th></tr></thead><tbody><tr><td>United States of America</td><td>3158</td><td>152853420612</td><td>48401969.79</td><td>451485183306</td><td>142965542.53</td></tr><tr><td>United Kingdom</td><td>609</td><td>23402005612</td><td>38426938.61</td><td>67302241475</td><td>110512711.78</td></tr><tr><td>France</td><td>482</td><td>10929166044</td><td>22674618.35</td><td>25413665738</td><td>52725447.59</td></tr><tr><td>Canada</td><td>251</td><td>8545103619</td><td>34044237.53</td><td>23660549333</td><td>94265136.78</td></tr><tr><td>New Zealand</td><td>37</td><td>4636500000</td><td>125310810.81</td><td>16364526983</td><td>442284513.05</td></tr><tr><td>Japan</td><td>34</td><td>2112000000</td><td>62117647.06</td><td>16154315861</td><td>475126937.09</td></tr><tr><td>Australia</td><td>135</td><td>7864638285</td><td>58256579.89</td><td>15614907982</td><td>115665985.05</td></tr><tr><td>Germany</td><td>185</td><td>6044250000</td><td>32671621.62</td><td>13965180409</td><td>75487461.67</td></tr><tr><td>Taiwan</td><td>15</td><td>1935000000</td><td>129000000.00</td><td>8450653917</td><td>563376927.80</td></tr><tr><td>India</td><td>66</td><td>3223250000</td><td>48837121.21</td><td>8352110374</td><td>126547126.88</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.
