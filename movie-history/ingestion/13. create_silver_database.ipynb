-- %%
CREATE SCHEMA IF NOT EXISTS movie_silver
MANAGED LOCATION "abfss://silver@stmoviesdatabricks.dfs.core.windows.net/";

-- %%
DESC DATABASE EXTENDED movie_silver;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database_description_item</th><th>database_description_value</th></tr></thead><tbody><tr><td>Catalog Name</td><td>movie_curso_databricks_7405606527054655</td></tr><tr><td>Namespace Name</td><td>movie_silver</td></tr><tr><td>Comment</td><td></td></tr><tr><td>Location</td><td>abfss://silver@stmoviesdatabricks.dfs.core.windows.net/__unitystorage/schemas/7d71b103-1397-44c4-85ac-d08e56258c05</td></tr><tr><td>Owner</td><td>wilder.a2182@hotmail.com</td></tr><tr><td>RootLocation</td><td>abfss://silver@stmoviesdatabricks.dfs.core.windows.net/</td></tr><tr><td>Properties</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_eastus)</td></tr></tbody></table></div>
