-- %%
USE movie_gold

-- %%
SELECT company_name,
        COUNT(company_name) AS total_movies,
        SUM(budget) AS total_budget,
        CAST(AVG(budget) AS DECIMAL(18,2)) AS avg_budget,
        SUM(revenue) AS total_revenue,
        CAST(AVG(revenue) AS DECIMAL(18,2)) AS avg_revenue
FROM results_movies
GROUP BY company_name
ORDER BY total_revenue DESC
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_name</th><th>total_movies</th><th>total_budget</th><th>avg_budget</th><th>total_revenue</th><th>avg_revenue</th></tr></thead><tbody><tr><td>Warner Bros.</td><td>444</td><td>28675493949</td><td>64584445.83</td><td>7.695762126636115E10</td><td>178971212.25</td></tr><tr><td>Universal Pictures</td><td>454</td><td>20952812900</td><td>46151570.26</td><td>6.033160263583709E10</td><td>136806355.18</td></tr><tr><td>Twentieth Century Fox Film Corporation</td><td>291</td><td>15873682800</td><td>54548738.14</td><td>5.214469481955804E10</td><td>184910265.32</td></tr><tr><td>Paramount Pictures</td><td>376</td><td>19719612948</td><td>52445779.12</td><td>5.012135158866841E10</td><td>140003775.39</td></tr><tr><td>Columbia Pictures</td><td>253</td><td>15295994736</td><td>60458477.22</td><td>3.7372812620935165E10</td><td>153797582.80</td></tr><tr><td>Walt Disney Pictures</td><td>133</td><td>11030280000</td><td>82934436.09</td><td>3.3195621796924137E10</td><td>263457315.85</td></tr><tr><td>New Line Cinema</td><td>217</td><td>8801485000</td><td>40559838.71</td><td>2.8797920836611813E10</td><td>138451542.48</td></tr><tr><td>Village Roadshow Pictures</td><td>131</td><td>9311800003</td><td>71082442.77</td><td>2.2569846344757378E10</td><td>177715325.55</td></tr><tr><td>Dune Entertainment</td><td>83</td><td>6290000003</td><td>75783132.57</td><td>22181024129</td><td>277262801.61</td></tr><tr><td>Relativity Media</td><td>152</td><td>7863293304</td><td>51732192.79</td><td>19116748600</td><td>127444990.67</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.

-- %%
SELECT company_name,
        COUNT(company_name) AS total_movies,
        SUM(budget) AS total_budget,
        CAST(AVG(budget) AS DECIMAL(18,2)) AS avg_budget,
        SUM(revenue) AS total_revenue,
        CAST(AVG(revenue) AS DECIMAL(18,2)) AS avg_revenue
FROM results_movies
WHERE year_release_date BETWEEN 2010 AND 2015
GROUP BY company_name
ORDER BY total_revenue DESC
LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>company_name</th><th>total_movies</th><th>total_budget</th><th>avg_budget</th><th>total_revenue</th><th>avg_revenue</th></tr></thead><tbody><tr><td>Warner Bros.</td><td>81</td><td>6812900003</td><td>84109876.58</td><td>17950314393</td><td>221608819.67</td></tr><tr><td>Paramount Pictures</td><td>54</td><td>5092000000</td><td>94296296.30</td><td>17531167407</td><td>324651248.28</td></tr><tr><td>Universal Pictures</td><td>92</td><td>4947600000</td><td>53778260.87</td><td>17341860642</td><td>188498485.24</td></tr><tr><td>Columbia Pictures</td><td>68</td><td>5277000000</td><td>77602941.18</td><td>16253282193</td><td>239018855.78</td></tr><tr><td>Walt Disney Pictures</td><td>33</td><td>4365000000</td><td>132272727.27</td><td>13503471549</td><td>409196107.55</td></tr><tr><td>Twentieth Century Fox Film Corporation</td><td>47</td><td>3670000000</td><td>78085106.38</td><td>11405640799</td><td>242673208.49</td></tr><tr><td>New Line Cinema</td><td>36</td><td>3090600000</td><td>85850000.00</td><td>11354065408</td><td>315390705.78</td></tr><tr><td>Marvel Studios</td><td>12</td><td>2200000000</td><td>183333333.33</td><td>10224978512</td><td>852081542.67</td></tr><tr><td>Legendary Pictures</td><td>28</td><td>3252000000</td><td>116142857.14</td><td>9698346099</td><td>346369503.54</td></tr><tr><td>Metro-Goldwyn-Mayer (MGM)</td><td>24</td><td>2700000000</td><td>112500000.00</td><td>9209502499</td><td>383729270.79</td></tr></tbody></table></div>
-- Databricks visualization. Run in Databricks to view.
